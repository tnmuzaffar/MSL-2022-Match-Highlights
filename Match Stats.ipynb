# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Arc

# %%
# %matplotlib inline

# %%
data = pd.read_csv("Match Stats.csv")
print(data)
# Out:
#      First Half                Team            Player           Event   X   Y  \
# 0           NaN  Negeri Sembilan FC         Khuzaimie       Long Pass  33  85
# 1           NaN  Negeri Sembilan FC             Alves            Shot  82  43
# 2           NaN            Sabah FC   Badrol Bakhtiar           Cross   1  25
# 3           NaN            Sabah FC   Saddil Ramdani             Pass  15  62
# 4           NaN  Negeri Sembilan FC     Herold Goulon      Clear Ball  11  51
# 5           NaN            Sabah FC       Park Tae Su            Shot  24  41
# 6           NaN  Negeri Sembilan FC           Gustavo            Pass  69  39
# 7           NaN  Negeri Sembilan FC             Alves  Shot On Target  82  30
# 8           NaN            Sabah FC     Khairul Fahmi           Saves  97  49
# 9           NaN  Negeri Sembilan FC     Herold Goulon            Pass  59  88
# 10          NaN  Negeri Sembilan FC        Che Rashid            Pass  63  95
# ...

# %%
data.head(10)
# Out:
#   First Half                Team           Player           Event   X   Y  X2  \
# 0        NaN  Negeri Sembilan FC        Khuzaimie       Long Pass  33  85  82
# 1        NaN  Negeri Sembilan FC            Alves            Shot  82  43  97
# 2        NaN            Sabah FC  Badrol Bakhtiar           Cross   1  25  15
# 3        NaN            Sabah FC  Saddil Ramdani             Pass  15  62  10
# 4        NaN  Negeri Sembilan FC    Herold Goulon      Clear Ball  11  51  22
# 5        NaN            Sabah FC      Park Tae Su            Shot  24  41   2
# 6        NaN  Negeri Sembilan FC          Gustavo            Pass  69  39  78
# 7        NaN  Negeri Sembilan FC            Alves  Shot On Target  82  30  97
# 8        NaN            Sabah FC    Khairul Fahmi           Saves  97  49  94
# 9        NaN  Negeri Sembilan FC    Herold Goulon            Pass  59  88  63
#
#    Y2 Unnamed: 8  Unnamed: 9  Unnamed: 10
# 0  42        NaN         NaN          NaN
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)

for i in range(len(data)):
    plt.plot([int(data["X"][i]),int(data["X2"][i])],
            [int(data["Y"] [i]), int(data["Y2"][i])],
            color="red")
    
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(7, 5)

for i in range(len(data)):
    plt.plot([int(data["X"][i]),int(data["X2"][i])],
            [int(data["Y"] [i]), int(data["Y2"][i])],
            color="red")
    
    plt.plot(int(data["X"][i]),int(data["Y"][i]),">", color="blue")
    
plt.show()

# %%
#Create figure
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)

#Pitch Outline & Centre Line
plt.plot([0,0],[0,90], color="black")
plt.plot([0,130],[90,90], color="black")
plt.plot([130,130],[90,0], color="black")
plt.plot([130,0],[0,0], color="black")
plt.plot([65,65],[0,90], color="black")

#Left Penalty Area
plt.plot([16.5,16.5],[65,25],color="black")
plt.plot([0,16.5],[65,65],color="black")
plt.plot([16.5,0],[25,25],color="black")

#Right Penalty Area
plt.plot([130,113.5],[65,65],color="black")
plt.plot([113.5,113.5],[65,25],color="black")
plt.plot([113.5,130],[25,25],color="black")

#Left 6-yard Box
plt.plot([0,5.5],[54,54],color="black")
plt.plot([5.5,5.5],[54,36],color="black")
plt.plot([5.5,0.5],[36,36],color="black")

#Right 6-yard Box
plt.plot([130,124.5],[54,54],color="black")
plt.plot([124.5,124.5],[54,36],color="black")
plt.plot([124.5,130],[36,36],color="black")

#Prepare Circles
centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
centreSpot = plt.Circle((65,45),0.8,color="black")
leftPenSpot = plt.Circle((11,45),0.8,color="black")
rightPenSpot = plt.Circle((119,45),0.8,color="black")

#Draw Circles
ax.add_patch(centreCircle)
ax.add_patch(centreSpot)
ax.add_patch(leftPenSpot)
ax.add_patch(rightPenSpot)

#Prepare Arcs
leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

#Draw Arcs
ax.add_patch(leftArc)
ax.add_patch(rightArc)

#Tidy Axes
plt.axis('off')

for i in range(len(data)):
    plt.plot([int(data["X"][i]),int(data["X2"][i])],[int(data["Y"][i]),int(data["Y2"][i])], color="blue")
    plt.plot(int(data["X"][i]),int(data["Y"][i]),">", color="green")

#Display Pitch
plt.show()
